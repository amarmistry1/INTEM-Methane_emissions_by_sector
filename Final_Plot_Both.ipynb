# %%
import pandas as pd
from itertools import takewhile
import plotly.graph_objects as go
import base64
import numpy as np
from dare_viz import path

# %%
xlsCH4 = pd.ExcelFile('GBR_2022_2020_10052022_142545.xlsx')
dfCH4 = pd.read_excel(xlsCH4, 'Table10s3', header=4)
dfCH4.set_index("GREENHOUSE GAS SOURCE AND SINK CATEGORIES", inplace=True)
dfCH4.dropna(inplace=True)

# %%
dfCH4.drop(
    labels = ["D.  Non-energy products from fuels and solvent use", "G.  Other product manufacture and use ", "C.  Rice cultivation", "D.  Agricultural soils", "E.  Prescribed burning of savannas", "F.  Other land", "E.  Other ","6.  Other (as specified in summary 1.A)", "International bunkers", "Navigation", "Multilateral operations",
 "Aviation"],
    axis=0,
    inplace = True
)
dfCH4.drop(
    labels = ["Base year(1)", "Change from base to latest reported year"],
    axis=1,
    inplace = True
)
#dfCH4

# %% [markdown]
# Convert Inventory data to CO2equ

# %%
dfCH4_CO2_equ = dfCH4 / 1000 * 28
dfCH4_CO2_equ
# Out:
#                                                           1990        1991  \
# GREENHOUSE GAS SOURCE AND SINK CATEGORIES
# 1. Energy                                            41.893554   42.472735
# A. Fuel combustion (sectoral approach)                3.624305     3.76515
# 1.  Energy industries                                 0.261169    0.260316
# 2.  Manufacturing industries and construction         0.128494    0.131914
# 3.  Transport                                         1.419076    1.402901
# 4.  Other sectors                                     1.811582    1.966984
# 5.  Other                                             0.003983    0.003036
# B. Fugitive emissions from fuels                     38.269249   38.707585
# 1.  Solid fuels                                       24.44608   25.139311
# 2.  Oil and natural gas and other emissions fro...   13.823169   13.568274
# 2.  Industrial processes                              0.326988    0.318125
# B.  Chemical industry                                 0.248228    0.248492
# C.  Metal industry                                    0.043922    0.041378
# H.  Other                                             0.034838    0.028254
# 3.  Agriculture                                      32.815619   32.395744
# A.  Enteric fermentation                             27.644974   27.291376
# B.  Manure management                                 4.657829    4.614482
# J.  Other                                             0.303857    0.306105
# 4. Land use, land-use change and forestry             5.312559    5.308176
# A.  Forest land                                       0.098043    0.102038
# B.  Cropland                                          0.326975    0.326696
# C.  Grassland                                         2.672174    2.662766
# D.  Wetlands                                          2.197103    2.198649
# E.  Settlements                                         0.0041    0.003916
# H.  Other                                             0.014164     0.01411
# 5.  Waste                                            70.367513   71.070702
# A.  Solid waste disposal                             67.636281   68.313793
# B.  Biological treatment of solid waste               0.020308    0.046046
# C.  Incineration and open burning of waste            0.152676    0.149466
# D.  Waste water treatment and discharge               2.558248    2.561397
# Total CH4 emissions without CH4 from LULUCF         145.403673  146.257307
# Total CH4 emissions with CH4 from LULUCF            150.716232  151.565483
#
#                                                           1992        1993  \
# GREENHOUSE GAS SOURCE AND SINK CATEGORIES
# 1. Energy                                            41.944533   39.787822
# A. Fuel combustion (sectoral approach)                3.563885    3.643731
# 1.  Energy industries                                 0.266051    0.277824
# 2.  Manufacturing industries and construction         0.132401    0.122577
# 3.  Transport                                         1.385766    1.324735
# 4.  Other sectors                                     1.776751    1.915538
# 5.  Other                                             0.002916    0.003058
# B. Fugitive emissions from fuels                     38.380648   36.144091
# 1.  Solid fuels                                      24.930209   23.214902
# 2.  Oil and natural gas and other emissions fro...   13.450438   12.929189
# GREENHOUSE GAS SOURCE AND SINK CATEGORIES
# 1. Energy                                            7.111938   6.595589
# A. Fuel combustion (sectoral approach)               1.375673   1.350114
# 1.  Energy industries                                0.434235   0.427896
# 2.  Manufacturing industries and construction        0.144203   0.150268
# 3.  Transport                                        0.109367   0.085924
# 4.  Other sectors                                    0.686639   0.684981
# 5.  Other                                             0.00123   0.001046
# B. Fugitive emissions from fuels                     5.736265   5.245475
# 1.  Solid fuels                                      0.547649   0.531666
# 2.  Oil and natural gas and other emissions fro...   5.188615    4.71381
# 2.  Industrial processes                             0.094984   0.090448
# B.  Chemical industry                                0.076607    0.07527
# C.  Metal industry                                   0.012392   0.012242
# H.  Other                                            0.005985   0.002936
# 3.  Agriculture                                     28.313484  27.935965
# A.  Enteric fermentation                            23.789415  23.450111
# B.  Manure management                                 4.30078    4.26945
# J.  Other                                            0.223289   0.216404
# 4. Land use, land-use change and forestry            5.491092   5.462425
# A.  Forest land                                      0.135317   0.115504
# B.  Cropland                                         0.313299   0.312853
# C.  Grassland                                         2.70521   2.711404
# D.  Wetlands                                          2.30384   2.288851
# E.  Settlements                                      0.017512   0.017664
# H.  Other                                            0.015914   0.016148
# 5.  Waste                                           19.172907   17.74919
# A.  Solid waste disposal                            15.850301  14.461597
# B.  Biological treatment of solid waste              1.357593   1.362805
# C.  Incineration and open burning of waste           0.009001   0.008276
# D.  Waste water treatment and discharge              1.956012   1.916512
# Total CH4 emissions without CH4 from LULUCF         54.693313  52.371192
# Total CH4 emissions with CH4 from LULUCF            60.184405  57.833617
#
# [32 rows x 31 columns]

# %% [markdown]
# Read in InTEM data

# %%
def read_intem(species):

    fname = path() / f"data/intem/Table_UK_2021_{species}.txt"

    with open(fname, "r") as f:
        headiter = takewhile(lambda s: s.startswith('#'), f)
        header = list(headiter)

    df = pd.read_csv(fname,
                    sep=",",
                    skipinitialspace=True,
                    index_col="Year",
                    comment="#")

    df = df.apply(pd.to_numeric, errors='ignore')
    df.index = pd.to_datetime(df.index, format='%Y')
    df.rename(columns = {"Invent2021": "Invent"}, inplace=True)

    for h in header:
        if "GAS" in h:
            species_str = h.split(":")[1].strip()
        if "UNITS" in h:
            species_units = h.split(":")[1].strip()
        if "GWP" in h:
            species_gwp = float(h.split(":")[1].strip())
    
    return df, species_str, species_units, species_gwp

# %%
df_ch4, _, _, _ = read_intem("ch4")
df_n2o, _, _, _ = read_intem("n2o")

# %% [markdown]
# Break down emissions by sectors

# %%
df_ch4["InTEM_Energy"] = df_ch4["InTEM"] *0.183633889
df_ch4["InTEM_Industry"] = df_ch4["InTEM"] *0.001786693
df_ch4["InTEM_Agriculture"] = df_ch4["InTEM"] *0.294217933
df_ch4["InTEM_LULUCF"] = df_ch4["InTEM"] *0.051991413
df_ch4["InTEM_Waste"] = df_ch4["InTEM"] *0.468370072
df_ch4
# Out:
#             Invent  Invent_std  InTEM  InTEM_std  InTEM_Energy  \
# Year
# 1990-01-01  150.08       17.92  62.16      10.36     11.414683
# 1991-01-01  150.64       17.92  61.88       9.80     11.363265
# 1992-01-01  150.64       17.64  56.00       9.24     10.283498
# 1993-01-01  148.96       17.36  57.40       9.24     10.540585
# 1994-01-01  141.12       16.24  64.12       8.68     11.774605
# 1995-01-01  143.08       16.24  59.36       7.84     10.900508
# 1996-01-01  142.24       15.96  72.24       8.40     13.265712
# 2015-01-01        0.108559          17.876682      3.158998    28.458166
# 2016-01-01        0.107559          17.711920      3.129883    28.195878
# 2017-01-01        0.103056          16.970490      2.998865    27.015586
# 2018-01-01        0.107059          17.629539      3.115325    28.064735
# 2019-01-01        0.101556          16.723347      2.955192    26.622155
# 2020-01-01        0.097053          15.981918      2.824174    25.441862
# 2021-01-01        0.100555          16.558585      2.926077    26.359868

# %%
fig = go.Figure()

alpha = 0.6
color_1 = ["rgba(86, 119, 194, 1)", f"rgba(86, 119, 194, {alpha})"]
color_2 = ["rgba(99, 182, 137, 1)", f"rgba(99, 182, 137, {alpha})"]
color_3 = ["rgba(238,92,66, 1)", f"rgba(238,92,66, {alpha})"]
color_4 = ["rgba(255,215,0, 1)", f"rgba(255,215,0, {alpha})"]
color_5 = ["rgba(142,229,238, 1)", f"rgba(142,229,238, {alpha})"]
color_6 = ["rgba(0, 0, 0, 1)", f"rgba(0, 0, 0, {alpha})"]

date_range = [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
#date_range = ["2019-03-01", "2019-06-01"]

fig.add_trace(go.Scatter(
    x=date_range,
    y=dfCH4_CO2_equ.loc["1. Energy"],
    mode='lines',
    line=dict(color=color_1[0], width=3.),
    showlegend=True,
    name="Energy",
    ))

fig.add_trace(go.Scatter(
    x=date_range,
    y=dfCH4_CO2_equ.loc["2.  Industrial processes"],
    mode='lines',
    line=dict(color=color_2[0], width=3.),
    showlegend=True,
    name="Industrial processes",
    ))

fig.add_trace(go.Scatter(
    x=date_range,
    y=dfCH4_CO2_equ.loc["3.  Agriculture"],
    mode='lines',
    line=dict(color=color_3[0], width=3.),
    showlegend=True,
    name="Agriculture",
    ))

fig.add_trace(go.Scatter(
    x=date_range,
    y=dfCH4_CO2_equ.loc["4. Land use, land-use change and forestry"],
    mode='lines',
    line=dict(color=color_4[0], width=3.),
    showlegend=True,
    name="Land use, Land-use change and forestry",
    ))

fig.add_trace(go.Scatter(
    x=date_range,
    y=dfCH4_CO2_equ.loc["5.  Waste"],
    mode='lines',
    line=dict(color=color_5[0], width=3.),
    showlegend=True,
    name="Waste",
    ))

fig.add_trace(go.Scatter(
    x=date_range,
    y=df_ch4["InTEM_Energy"],
    mode='lines',
    line=dict(color=color_1[0], dash="dot", width=5),
    showlegend=False,
    hovertemplate = 'InTEM %{x|%Y}: %{y:.0f} Gt yr⁻¹<extra></extra>',
    name="InTEM",
    ))

fig.add_trace(go.Scatter(
    x=date_range,
    y=df_ch4["InTEM_Industry"],
    mode='lines',
    line=dict(color=color_2[0], dash="dot", width=5),
    showlegend=False,
    hovertemplate = 'InTEM %{x|%Y}: %{y:.0f} Gt yr⁻¹<extra></extra>',
    name="InTEM",
    ))

fig.add_trace(go.Scatter(
    x=date_range,
    y=df_ch4["InTEM_Agriculture"],
    mode='lines',
    line=dict(color=color_3[0], dash="dot", width=5),
    showlegend=False,
    hovertemplate = 'InTEM %{x|%Y}: %{y:.0f} Gt yr⁻¹<extra></extra>',
    name="InTEM",
    ))

fig.add_trace(go.Scatter(
    x=date_range,
    y=df_ch4["InTEM_LULUCF"],
    mode='lines',
    line=dict(color=color_4[0], dash="dot", width=5),
    showlegend=False,
    hovertemplate = 'InTEM %{x|%Y}: %{y:.0f} Gt yr⁻¹<extra></extra>',
    name="InTEM",
    ))

fig.add_trace(go.Scatter(
    x=date_range,
    y=df_ch4["InTEM_Waste"],
    mode='lines',
    line=dict(color=color_5[0], dash="dot", width=5),
    showlegend=False,
    hovertemplate = 'InTEM %{x|%Y}: %{y:.0f} Gt yr⁻¹<extra></extra>',
    name="InTEM",
    ))

fig.add_trace(go.Scatter(
    x=[pd.Timestamp("1900-01-01"), pd.Timestamp("1900-01-02")],
    y=[0., 0.],
    line=dict(color="black", dash="dot", width=4),
    marker=dict(opacity=0., size=0),
    showlegend=True,
    name="InTEM"
    ))

#fig.add_trace(go.Scatter(
#    x=date_range,
#    y=df_ch4["InTEM"],
#    mode='lines',
#    line=dict(color=color_6[0], dash="dot", width=5),
#    showlegend=False,
#    hovertemplate = 'Inventory %{x|%Y}: %{y:.0f} Gt yr⁻¹<extra></extra>',
#   name="InTEM",
#    ))


fig.update_layout(
    yaxis_title="Annual methane emissions (Gt yr)",
    template="simple_white",
    autosize=False,
    width=550*2,
    height=400*2,
    legend=dict(
        yanchor="top",
        y=0.99,
        xanchor="right",
        x=0.99,
        traceorder="normal"),
    margin=dict(l=55, r=10, t=10, b=40),
    # paper_bgcolor='rgba(0,0,0,0)',
    # plot_bgcolor='rgba(0,0,0,0)'
)

fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='Lightgrey')


fig.layout.font.size=20
fig.layout.font.family="Arial"

fig.write_image("Annual_methane_emissions_by_sector_BOTH.png")
fig.write_html("Annual_methane_emissions_by_sector_BOTH.html")

fig.show()

# %% [markdown]
# N2O data

# %%
xlsN2O = pd.ExcelFile('GBR_2022_2020_10052022_142545.xlsx')
dfN2O = pd.read_excel(xlsN2O, 'Table10s4', header=4)
dfN2O.set_index("GREENHOUSE GAS SOURCE AND SINK CATEGORIES", inplace=True)
dfN2O.dropna(inplace=True)
#dfN2O

# %%
dfN2O.drop(
    labels = ["D.  Non-energy products from fuels and solvent use",  "E.  Prescribed burning of savannas", "F.  Other land", "E.  Other ","6.  Other (as specified in summary 1.A)", "International bunkers", "Navigation", "Multilateral operations",
 "Aviation", "Indirect N2O", "H.  Other "],
    axis=0,
    inplace = True
)
dfN2O.drop(
    labels = ["Base year(1)", "Change from base to latest reported year"],
    axis=1,
    inplace = True
)
#dfN2O

# %%
dfN2O_CO2_equ = dfN2O / 1000 * 265
dfN2O_CO2_equ
# Out:
#                                                          1990       1991  \
# GREENHOUSE GAS SOURCE AND SINK CATEGORIES
# 1. Energy                                            3.285956   3.264935
# A. Fuel combustion (sectoral approach)               3.246137    3.22632
# 1.  Energy industries                                 1.27773   1.264945
# 2.  Manufacturing industries and construction        0.280459   0.278801
# 3.  Transport                                        1.282627   1.262918
# 4.  Other sectors                                    0.355414   0.377863
# 5.  Other                                            0.049908   0.041793
# B. Fugitive emissions from fuels                     0.039819   0.038615
# 1.  Solid fuels                                       0.00008   0.000033
# 2.  Oil and natural gas and other emissions fro...   0.039738   0.038583
# 2.  Industrial processes                            21.710464  21.860542
# B.  Chemical industry                                 21.1621  21.311801
# C.  Metal industry                                   0.018432   0.016916
# G.  Other product manufacture and use                0.529931   0.531825
# 3.  Agriculture                                     16.204651  16.274696
# B.  Manure management                                3.053539   3.035164
# D.  Agricultural soils                              12.940808  13.035955
# J.  Other                                            0.159032   0.158482
# 4. Land use, land-use change and forestry             2.18564    2.17345
# A.  Forest land                                      0.669528   0.671855
# B.  Cropland                                          0.65325   0.650658
# C.  Grassland                                        0.022957   0.022326
# D.  Wetlands                                         0.018935   0.018881
# E.  Settlements                                      0.391871   0.384718
# H.  Other                                            0.157439   0.156986
# 5.  Waste                                            0.851132   0.858536
# B.  Biological treatment of solid waste              0.011532   0.026126
# C.  Incineration and open burning of waste           0.045286   0.043635
# D.  Waste water treatment and discharge              0.794314   0.788774
# Total direct N2O emissions without N2O from LULUCF  42.052203  42.258709
# Total direct N2O emissions with N2O from LULUCF     44.237843  44.432159
#
#                                                          1992       1993  \
# GREENHOUSE GAS SOURCE AND SINK CATEGORIES
# 1. Energy                                
\
# GREENHOUSE GAS SOURCE AND SINK CATEGORIES
# 1. Energy                                            3.208507   3.107244
# A. Fuel combustion (sectoral approach)               3.153251   3.058091
# 1.  Energy industries                                 1.01698   0.954882
# 2.  Manufacturing industries and construction         0.25793   0.244279
# 3.  Transport                                        1.549639   1.552822
# 4.  Other sectors                                    0.292241   0.270832
# 5.  Other                                            0.036461   0.035277
# B. Fugitive emissions from fuels                     0.055257   0.049153
# 1.  Solid fuels                                      0.000025   0.000017
# 2.  Oil and natural gas and other emissions fro...   0.055231   0.049136
# 2.  Industrial processes                            13.166306  13.325989
# B.  Chemical industry                               12.630808  12.791201
# C.  Metal industry                                   0.018269   0.018885
# G.  Other product manufacture and use                0.517228   0.515903
# 3.  Agriculture                                     16.201504  16.445324
# B.  Manure management                                3.220315   3.264805
# D.  Agricultural soils                              12.830133  13.027195
# J.  Other                                            0.151056   0.153324
# 4. Land use, land-use change and forestry            2.078957    2.06996
# A.  Forest land                                      0.682737   0.692018
# B.  Cropland                                         0.608884   0.596621
# C.  Grassland                                        0.020466   0.020321
# D.  Wetlands                                         0.018612   0.018558
# E.  Settlements                                      0.348256   0.345561
# H.  Other                                            0.155168   0.154862
# 5.  Waste                                            0.976627   0.993636
# B.  Biological treatment of solid waste              0.099111    0.11371
# C.  Incineration and open burning of waste           0.041359   0.031091
# D.  Waste water treatment and discharge              0.836157   0.848835
# Total direct N2O emissions without N2O from LULUCF  33.552945  33.872193
# Total direct N2O emissions with N2O from LULUCF     35.631902  35.942153
#
#                                                          1998       1999  ...  \
# GREENHOUSE GAS SOURCE AND SINK CATEGORIES                                 ...
# 1. Energy                                            3.128601   3.058019  ...
# A. Fuel combustion (sectoral approach)               3.078366    3.01708  ...
# 1.  Energy industries                                1.003794   0.941172  ...
# 2.  Manufacturing industries and construction        0.241303    0.23274  ...
# 3.  Transport                                        1.540839   1.552278  ...
# 4.  Other sectors                                    0.262208   0.260693  ...
# 5.  Other                                            0.030223   0.030197  ...
# B. Fugitive emissions from fuels                     0.050235    0.04094  ...
# 1.  Solid fuels                                      0.000029   0.000015  ...
# 2.  Oil and natural gas and other emissions fro...   0.050207   0.040925  ...
# 2.  Industrial processes                            13.569144   5.125104  ...
# B.  Chemical industry                               13.030556    4.58156  ...
# C.  Metal industry                                   0.017514   0.017961  ...
# G.  Other product manufacture and use                0.521074   0.525583  ...
# 3.  Agriculture                                     16.176713  16.223455  ...
# B.  Manure management                                3.226704   3.134607  ...
# D.  Agricultural soils                              12.796137  12.932957  ...
# J.  Other                                            0.153872   0.155891  ...
# 4. Land use, land-use change and forestry            2.037822   2.004482  ...
# A.  Forest land                                      0.693335    0.69492  ...
# B.  Cropland                                         0.579565   0.560463  ...
# C.  Grassland                                        0.019362   0.018938  ...
# D.  Wetlands                                         0.018504    0.01845  ...
# E.  Settlements                                      0.336692   0.328004  ...
# H.  Other                                            0.154566   0.154302  ...
# 5.  Waste                                            1.022028   1.025727  ...
# B.  Biological treatment of solid waste              0.128323   0.142929  ...
# C.  Incineration and open burning of waste           0.058412   0.059604  ...
# D.  Waste water treatment and discharge              0.835293   0.823195  ...
# Total direct N2O emissions without N2O from LULUCF  33.896486  25.432305  ...
# Total direct N2O emissions with N2O from LULUCF     35.934308  27.436787  ...
#
#                                                          2011       2012  \
# GREENHOUSE GAS SOURCE AND SINK CATEGORIES
# 1. Energy                                            2.150863   2.309117
# A. Fuel combustion (sectoral approach)               2.107613   2.276149
# 1.  Energy industries                                0.874099   1.016464
# 2.  Manufacturing industries and construction        0.180455   0.183006
# 3.  Transport                                        0.871175   0.889941
# 4.  Other sectors                                    0.155613   0.162673
# 5.  Other                                            0.026271   0.024065
# B. Fugitive emissions from fuels                      0.04325   0.032969
# 1.  Solid fuels                                      0.000065   0.000016
# 2.  Oil and natural gas and other emissions fro...   0.043185   0.032952
# 2.  Industrial processes                             1.043901   0.824494
# B.  Chemical industry                                0.178576   0.034512
# C.  Metal industry                                   0.009378   0.009791
# G.  Other product manufacture and use                0.855947   0.780191
# 3.  Agriculture                                     13.468656  13.303269
# B.  Manure management                                2.628067   2.594653
# D.  Agricultural soils                               10.73068  10.600574
# J.  Other                                            0.109909   0.108042
# 4. Land use, land-use change and forestry            1.705413   1.675437
# A.  Forest land                                      0.677286   0.677192
# B.  Cropland                                         0.388842   0.384131
# C.  Grassland                                        0.044039   0.026652
# D.  Wetlands                                         0.020046   0.020074
# E.  Settlements                                      0.263894   0.259411
# H.  Other                                            0.142477   0.141382
# 5.  Waste                                            1.380113   1.386519
# B.  Biological treatment of solid waste              0.467874   0.485488
# C.  Incineration and open burning of waste           0.063711   0.059811
# D.  Waste water treatment and discharge              0.848529   0.841221
# Total direct N2O emissions without N2O from LULUCF  18.043534  17.823399
# Total direct N2O emissions with N2O from LULUCF     19.748947  19.498836
#
#                                                          2013       2014  \
# GREENHOUSE GAS SOURCE AND SINK CATEGORIES
# 1. Energy                                            2.286534   2.222302
# A. Fuel combustion (sectoral approach)               2.255225   2.191072
# 1.  Energy industries                                0.984988   0.881654
# 2.  Manufacturing industries and construction        0.167014   0.185669
# 3.  Transport                                        0.914265    0.94909
# 4.  Other sectors                                    0.167131   0.155482
# 5.  Other                                            0.021828   0.019177
# B. Fugitive emissions from fuels                     0.031308    0.03123
# 1.  Solid fuels                                      0.000033   0.000059
# 2.  Oil and natural gas and other emissions fro...   0.031275   0.031172
# 2.  Industrial processes                             0.777342   0.796475
# B.  Chemical industry                                0.039876   0.037347
# C.  Metal industry                                    0.01173   0.011791
# G.  Other product manufacture and use                0.725735   0.747337
# 3.  Agriculture                                     13.436637  13.909054
# B.  Manure management                                 2.58535   2.598034
# D.  Agricultural soils                              10.742243  11.201433
# J.  Other                                            0.109044   0.109587
# 4. Land use, land-use change and forestry            1.661446   1.629311
# A.  Forest land                                       0.67883   0.661313
# B.  Cropland                                          0.37505   0.369273
# C.  Grassland                                        0.029794   0.030153
# D.  Wetlands                                         0.019283   0.019044
# E.  Settlements                                      0.254479   0.249142
# H.  Other                                            0.140905   0.140467
# 5.  Waste                                            1.413426   1.472933
# B.  Biological treatment of solid waste              0.519343   0.579228
# C.  Incineration and open burning of waste           0.058048    0.05134
# D.  Waste water treatment and discharge              0.836036   0.842365
# Total direct N2O emissions without N2O from LULUCF  17.913939  18.400764
# Total direct N2O emissions with N2O from LULUCF     19.575385  20.030075
#
#                                                          2015       2016  \
# GREENHOUSE GAS SOURCE AND SINK CATEGORIES
# 1. Energy                                            2.242441   2.109777
# A. Fuel combustion (sectoral approach)               2.210777   2.077081
# 1.  Energy industries                                0.850826   0.676562
# 2.  Manufacturing industries and construction        0.198402   0.199893
# 3.  Transport                                        0.984138   1.020617
# 4.  Other sectors                                    0.161833    0.16545
# 5.  Other                                            0.015578    0.01456
# B. Fugitive emissions from fuels                     0.031663   0.032696
# 1.  Solid fuels                                      0.000066   0.000017
# 2.  Oil and natural gas and other emissions fro...   0.031597   0.032678
# 2.  Industrial processes                             0.763157   0.772252
# B.  Chemical industry                                0.027558   0.023636
# C.  Metal industry                                   0.010359   0.006754
# G.  Other product manufacture and use                 0.72524   0.741862
# 3.  Agriculture                                     13.606263   13.43906
# B.  Manure management                                2.592119   2.585171
# D.  Agricultural soils                              10.907639  10.747497
# J.  Other                                            0.106505   0.106392
# 4. Land use, land-use change and forestry            1.620274   1.611513
# A.  Forest land                                      0.653874   0.649224
# B.  Cropland                                         0.364867   0.363045
# C.  Grassland                                        0.026944   0.029938
# D.  Wetlands                                         0.030554   0.020517
# E.  Settlements                                      0.247307   0.254255
# H.  Other                                            0.139524   0.138553
# 5.  Waste                                             1.48558   1.507267
# B.  Biological treatment of solid waste              0.582336   0.618844
# C.  Incineration and open burning of waste           0.049475   0.044095
# D.  Waste water treatment and discharge              0.853769   0.844329
# Total direct N2O emissions without N2O from LULUCF   18.09744  17.828357
# Total direct N2O emissions with N2O from LULUCF     19.717714   19.43987
#
#                                                          2017       2018  \
# GREENHOUSE GAS SOURCE AND SINK CATEGORIES
# 1. Energy                                            2.100562   2.131208
# A. Fuel combustion (sectoral approach)               2.067539   2.097989
# 1.  Energy industries                                0.633491    0.64059
# 2.  Manufacturing industries and construction        0.218895   0.233418
# 3.  Transport                                        1.034983   1.038684
# 4.  Other sectors                                    0.165194   0.169944
# 5.  Other                                            0.014975   0.015353
# B. Fugitive emissions from fuels                     0.033023   0.033219
# 1.  Solid fuels                                      0.000016    0.00001
# 2.  Oil and natural gas and other emissions fro...   0.033008   0.033209
# 2.  Industrial processes                             0.798955   0.780851
# B.  Chemical industry                                 0.03485   0.023573
# C.  Metal industry                                   0.006571   0.006434
# G.  Other product manufacture and use                0.757534   0.750844
# 3.  Agriculture                                       13.8057  13.678577
# B.  Manure management                                2.571979   2.537865
# D.  Agricultural soils                              11.126467  11.037445
# J.  Other                                            0.107254   0.103266
# 4. Land use, land-use change and forestry            1.595693   1.605117
# A.  Forest land                                      0.643251   0.649478
# B.  Cropland                                         0.359198   0.353321
# C.  Grassland                                        0.029502   0.030134
# D.  Wetlands                                         0.020173   0.026392
# E.  Settlements                                      0.251714    0.25613
# H.  Other                                            0.137791   0.136933
# 5.  Waste                                            1.554542   1.527388
# B.  Biological treatment of solid waste              0.643698   0.631939
# C.  Incineration and open burning of waste           0.040088   0.033692
# D.  Waste water treatment and discharge              0.870756   0.861757
# Total direct N2O emissions without N2O from LULUCF   18.25976  18.118024
# Total direct N2O emissions with N2O from LULUCF     19.855453  19.723141
#
#                                                          2019       2020
# GREENHOUSE GAS SOURCE AND SINK CATEGORIES
# 1. Energy                                             2.09926   1.915408
# A. Fuel combustion (sectoral approach)               2.066384    1.88792
# 1.  Energy industries                                0.635226   0.623444
# 2.  Manufacturing industries and construction        0.221835   0.222871
# 3.  Transport                                        1.026816   0.863881
# 4.  Other sectors                                    0.166119   0.164571
# 5.  Other                                            0.016388   0.013153
# B. Fugitive emissions from fuels                     0.032875   0.027488
# 1.  Solid fuels                                      0.000014   0.000015
# 2.  Oil and natural gas and other emissions fro...   0.032861   0.027474
# 2.  Industrial processes                             0.805246   0.721061
# B.  Chemical industry                                0.035425   0.045426
# C.  Metal industry                                   0.006425   0.006333
# G.  Other product manufacture and use                0.763396   0.669302
# 3.  Agriculture                                     13.652365  12.961309
# B.  Manure management                                2.534011   2.501978
# D.  Agricultural soils                               11.01363  10.358491
# J.  Other                                            0.104724   0.100841
# 4. Land use, land-use change and forestry            1.613935   1.588214
# A.  Forest land                                      0.648065   0.633378
# B.  Cropland                                          0.35254   0.354348
# C.  Grassland                                        0.034362   0.030132
# D.  Wetlands                                         0.032873   0.022062
# E.  Settlements                                      0.257888   0.260936
# H.  Other                                            0.135861   0.134607
# 5.  Waste                                            1.555428   1.563454
# B.  Biological treatment of solid waste              0.636139   0.635829
# C.  Incineration and open burning of waste            0.02775   0.023452
# D.  Waste water treatment and discharge               0.89154   0.904172
# Total direct N2O emissions without N2O from LULUCF  18.112299  17.161232
# Total direct N2O emissions with N2O from LULUCF     19.726234  18.749446
#
# [31 rows x 31 columns]

# %%
df_n2o["InTEM_Energy"] = df_n2o["InTEM"] *0.100978825
df_n2o["InTEM_Industry"] = df_n2o["InTEM"] *0.234918098
df_n2o["InTEM_Agriculture"] = df_n2o["InTEM"] *0.549240911
df_n2o["InTEM_LULUCF"] = df_n2o["InTEM"] *0.070015981
df_n2o["InTEM_Waste"] = df_n2o["InTEM"] *0.044846185
df_n2o
# Out:
#             Invent  Invent_std   InTEM  InTEM_std  InTEM_Energy  \
# Year
# 1990-01-01  43.990       6.519     NaN        NaN           NaN
# 1991-01-01  44.255       6.439     NaN        NaN           NaN
# 1992-01-01  39.750       5.697     NaN        NaN           NaN
# 1993-01-01  36.040       5.061     NaN        NaN           NaN
# 1994-01-01  36.570       5.061     NaN        NaN           NaN
# 1995-01-01  35.510       4.823  23.532      5.099      2.376234
# 1996-01-01  35.510       4.717  33.655      5.141      3.398442
# 1997-01-01  35.775       4.664  28.090      5.803      2.836495
# 1998-01-01  35.775       4.558  33.390      5.618      3.371683
# 1999-01-01  27.030       3.392  27.560      5.856      2.782976
# 2000-01-01  26.500       3.260  21.200      4.614      2.140751
# 2001-01-01  25.122       3.021  24.672      5.340      2.491350
# 2002-01-01  23.665       2.785  22.976      5.401      2.320089
# 2003-01-01  23.267       2.682  25.122      5.271      2.536790
# 2004-01-01  23.691       2.671  28.355      5.194      2.863255
# 2005-01-01  22.896       2.525  24.989      4.842      2.523360
# 2006-01-01  21.863       2.356  21.279      5.486      2.148728
# 2007-01-01  21.889       2.303  27.560      5.141      2.782976
# 2008-01-01  21.253       2.184  19.265      4.852      1.945357
# 2009-01-01  19.901       1.993  19.345      4.993      1.953435
# 2010-01-01  20.273       1.982  20.193      4.730      2.039065
# 2011-01-01  19.584       1.863  19.265      5.496      1.945357
# 2012-01-01  19.424       1.799  26.765      2.994      2.702698
# 2013-01-01  19.372       1.746  24.300      2.531      2.453785
# 2014-01-01  19.981       1.749  24.195      2.027      2.443183
# 2015-01-01  19.610       1.667  22.340      1.871      2.255867
# 2016-01-01  19.398       1.601  24.433      1.956      2.467216
# 2017-01-01  19.796       1.585  24.300      1.863      2.453785
# 2018-01-01  19.610       1.521  24.777      2.003      2.501952
# 2019-01-01  19.769       1.484  22.525      1.720      2.274548
# 2020-01-01     NaN         NaN  22.075      1.799      2.229108
# 2021-01-01     NaN         NaN  22.340      2.181      2.255867
#
#             InTEM_Industry  InTEM_Agriculture  InTEM_LULUCF  InTEM_Waste
# Year
# 1990-01-01             NaN                NaN           NaN          NaN
# 1991-01-01             NaN                NaN           NaN          NaN
# 1992-01-01             NaN                NaN           NaN          NaN
# 1993-01-01             NaN                NaN           NaN          NaN
# 1994-01-01             NaN                NaN           NaN          NaN
# 1995-01-01        5.528093          12.924737      1.647616     1.055320
# 1996-01-01        7.906169          18.484703      2.356388     1.509298
# 1997-01-01        6.598849          15.428177      1.966749     1.259729
# 1998-01-01        7.843915          18.339154      2.337834     1.497414
# 1999-01-01        6.474343          15.137080      1.929640     1.235961
# 2000-01-01        4.980264          11.643907      1.484339     0.950739
# 2001-01-01        5.795899          13.550872      1.727434     1.106445
# 2002-01-01        5.397478          12.619359      1.608687     1.030386
# 2003-01-01        5.901612          13.798030      1.758941     1.126626
# 2004-01-01        6.661103          15.573726      1.985303     1.271614
# 2005-01-01        5.870368          13.724981      1.749629     1.120661
# 2006-01-01        4.998822          11.687297      1.489870     0.954282
# 2007-01-01        6.474343          15.137080      1.929640     1.235961
# 2008-01-01        4.525697          10.581126      1.348858     0.863962
# 2009-01-01        4.544491          10.625065      1.354459     0.867549
# 2010-01-01        4.743701          11.090822      1.413833     0.905579
# 2011-01-01        4.525697          10.581126      1.348858     0.863962
# 2012-01-01        6.287583          14.700433      1.873978     1.200308
# 2013-01-01        5.708510          13.346554      1.701388     1.089762
# 2014-01-01        5.683843          13.288884      1.694037     1.085053
# 2015-01-01        5.248070          12.270042      1.564157     1.001864
# 2016-01-01        5.739754          13.419603      1.710700     1.095727
# 2017-01-01        5.708510          13.346554      1.701388     1.089762
# 2018-01-01        5.820566          13.608542      1.734786     1.111154
# 2019-01-01        5.291530          12.371652      1.577110     1.010160
# 2020-01-01        5.185817          12.124493      1.545603     0.989980
# 2021-01-01        5.248070          12.270042      1.564157     1.001864

# %%
fig1 = go.Figure()

alpha = 0.6
color_1 = ["rgba(86, 119, 194, 1)", f"rgba(86, 119, 194, {alpha})"]
color_2 = ["rgba(99, 182, 137, 1)", f"rgba(99, 182, 137, {alpha})"]
color_3 = ["rgba(238,92,66, 1)", f"rgba(238,92,66, {alpha})"]
color_4 = ["rgba(255,215,0, 1)", f"rgba(255,215,0, {alpha})"]
color_5 = ["rgba(142,229,238, 1)", f"rgba(142,229,238, {alpha})"]
color_6 = ["rgba(0, 0, 0, 1)", f"rgba(0, 0, 0, {alpha})"]

date_range = [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
#date_range = ["2019-03-01", "2019-06-01"]

fig1.add_trace(go.Scatter(
    x=date_range,
    y=dfN2O_CO2_equ.loc["1. Energy"],
    mode='lines',
    line=dict(color=color_1[0], width=3.),
    showlegend=True,
    name="Energy",
    ))

fig1.add_trace(go.Scatter(
    x=date_range,
    y=dfN2O_CO2_equ.loc["2.  Industrial processes"],
    mode='lines',
    line=dict(color=color_2[0], width=3.),
    showlegend=True,
    name="Industrial processes",
    ))

fig1.add_trace(go.Scatter(
    x=date_range,
    y=dfN2O_CO2_equ.loc["3.  Agriculture"],
    mode='lines',
    line=dict(color=color_3[0], width=3.),
    showlegend=True,
    name="Agriculture",
    ))

fig1.add_trace(go.Scatter(
    x=date_range,
    y=dfN2O_CO2_equ.loc["4. Land use, land-use change and forestry"],
    mode='lines',
    line=dict(color=color_4[0], width=3.),
    showlegend=True,
    name="Land use, Land-use change and forestry",
    ))

fig1.add_trace(go.Scatter(
    x=date_range,
    y=dfN2O_CO2_equ.loc["5.  Waste"],
    mode='lines',
    line=dict(color=color_5[0], width=3.),
    showlegend=True,
    name="Waste",
    ))

fig1.add_trace(go.Scatter(
    x=date_range,
    y=df_n2o["InTEM_Energy"],
    mode='lines',
    line=dict(color=color_1[0], dash="dot", width=5),
    showlegend=False,
    hovertemplate = 'InTEM %{x|%Y}: %{y:.0f} Gt yr⁻¹<extra></extra>',
    name="InTEM",
    ))

fig1.add_trace(go.Scatter(
    x=date_range,
    y=df_n2o["InTEM_Industry"],
    mode='lines',
    line=dict(color=color_2[0], dash="dot", width=5),
    showlegend=False,
    hovertemplate = 'InTEM %{x|%Y}: %{y:.0f} Gt yr⁻¹<extra></extra>',
    name="InTEM",
    ))

fig1.add_trace(go.Scatter(
    x=date_range,
    y=df_n2o["InTEM_Agriculture"],
    mode='lines',
    line=dict(color=color_3[0], dash="dot", width=5),
    showlegend=False,
    hovertemplate = 'InTEM %{x|%Y}: %{y:.0f} Gt yr⁻¹<extra></extra>',
    name="InTEM",
    ))

fig1.add_trace(go.Scatter(
    x=date_range,
    y=df_n2o["InTEM_LULUCF"],
    mode='lines',
    line=dict(color=color_4[0], dash="dot", width=5),
    showlegend=False,
    hovertemplate = 'InTEM %{x|%Y}: %{y:.0f} Gt yr⁻¹<extra></extra>',
    name="InTEM",
    ))

fig1.add_trace(go.Scatter(
    x=date_range,
    y=df_n2o["InTEM_Waste"],
    mode='lines',
    line=dict(color=color_5[0], dash="dot", width=5),
    showlegend=False,
    hovertemplate = 'InTEM %{x|%Y}: %{y:.0f} Gt yr⁻¹<extra></extra>',
    name="InTEM",
    ))

fig1.add_trace(go.Scatter(
    x=[pd.Timestamp("1900-01-01"), pd.Timestamp("1900-01-02")],
    y=[0., 0.],
    line=dict(color="black", dash="dot", width=4),
    marker=dict(opacity=0., size=0),
    showlegend=True,
    name="InTEM"
    ))

fig1.update_layout(
    yaxis_title="Annual N2O emissions (Gt yr)",
    template="simple_white",
    autosize=False,
    width=550*2,
    height=400*2,
    legend=dict(
        yanchor="top",
        y=0.99,
        xanchor="right",
        x=0.99,
        traceorder="normal"),
    margin=dict(l=55, r=10, t=10, b=40),
    # paper_bgcolor='rgba(0,0,0,0)',
    # plot_bgcolor='rgba(0,0,0,0)'
)


fig1.layout.font.size=20
fig1.layout.font.family="Arial"

fig1.write_image("Annual_N2O_emissions_by_sector_BOTH.png")
fig1.write_html("Annual_N2O_emissions_by_sector_BOTH.html")

fig1.show()
